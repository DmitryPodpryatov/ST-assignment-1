# %%
Ns = [100_000 * 10 ** n for n in range(5)]
memory_profiling = [31, 35, 69, 412, 3845]  # MiB
time_profiling = [0.001, 0.002, 0.002, 0.002, 0.002]  # s

# %%
import math


def actual_complexity(N):
    epsilon = 0.01
    log = math.log(epsilon * N)

    return 1 / epsilon * log * log


def nlogn(N):
    return N * math.log(N)

# %%
import matplotlib.pyplot as plt

plt.xscale('log')
plt.yscale('linear')
plt.plot(Ns, memory_profiling, label='Benchmarks')
plt.plot(Ns, [actual_complexity(N) for N in Ns], label='Actual')
plt.xlabel('N')
plt.ylabel('MiB')
plt.legend()
plt.show()
# Out:
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\numpy\.libs\libopenblas.jpijnswnnan3ce6lli5fwsphut2vxmth.gfortran-win_amd64.dll
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
plt.xscale('log')
plt.yscale('linear')
plt.plot(Ns, memory_profiling, label='Benchmarks')
plt.plot(Ns, [1 / 10 * actual_complexity(N) for N in Ns], label='Actual with coefficient')
plt.xlabel('N')
plt.ylabel('MiB')
plt.legend()
plt.show()

# %%
plt.xscale('log')
plt.yscale('linear')
plt.plot(Ns, memory_profiling, label='Benchmarks')
plt.plot(Ns, [1 / 10 * actual_complexity(N) for N in Ns], label='Actual with coefficient')
plt.plot(Ns, [nlogn(N) for N in Ns], label='N log N')
plt.xlabel('N')
plt.ylabel('MiB')
plt.legend()
plt.show()
